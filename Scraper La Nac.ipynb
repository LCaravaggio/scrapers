# %%
from bs4 import BeautifulSoup
import requests
import time
from datetime import date, timedelta
import shutil, sys

# %%
def download(name, file):
    image_url = name
    filename="c:/data/tapas/lanac/"+file+".jpg"
    # Open the url image, set stream to True, this will return the stream content.
    r = requests.get(image_url, stream = True)

    # Check if the image was retrieved successfully
    if r.status_code == 200:
        # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
        r.raw.decode_content = True
    
        # Open a local file with wb ( write binary ) permission.
        with open(filename,'wb') as f:
            shutil.copyfileobj(r.raw, f)
        
        print('Image sucessfully Downloaded: ',file)
    else:
        print('Image Couldn\'t be retreived')
        print(name)
        
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
print(sd.strftime("%Y")+sd.strftime("%m")+sd.strftime("%d"))
# Out:
# 20080101

# %%
start_date = date(2010, 1, 1)
end_date = date(2021, 7, 4)


for sd in daterange(start_date, end_date):    
    file=sd.strftime("%Y")+sd.strftime("%m")+sd.strftime("%d")
    name="https://img.kiosko.net/"+sd.strftime("%Y")+"/"+sd.strftime("%m")+"/"+sd.strftime("%d")+"/ar/nacion.750.jpg"
    try:
        download(name, file)
    except:
        print("no se pudo obtener " + name)
# Out:
# Image sucessfully Downloaded:  20100101
# Image Couldn't be retreived
# https://img.kiosko.net/2010/01/02/ar/nacion.750.jpg
# Image sucessfully Downloaded:  20100103
# Image sucessfully Downloaded:  20100104
# Image sucessfully Downloaded:  20100105
# Image sucessfully Downloaded:  20100106
# Image sucessfully Downloaded:  20100107
# Image sucessfully Downloaded:  20100108
# Image sucessfully Downloaded:  20100109
# Image Couldn't be retreived
# https://img.kiosko.net/2010/01/10/ar/nacion.750.jpg
# Image sucessfully Downloaded:  20100111
# Image sucessfully Downloaded:  20100112
# Image sucessfully Downloaded:  20100113
# Image sucessfully Downloaded:  20100114
# Image sucessfully Downloaded:  20100115
# Image sucessfully Downloaded:  20100116
# Image sucessfully Downloaded:  20100117
# Image sucessfully Downloaded:  20100118
# Image sucessfully Downloaded:  20100119
# Image sucessfully Downloaded:  20100120
# Image sucessfully Downloaded:  20100121
# ...
